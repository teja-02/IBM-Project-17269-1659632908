# %% [markdown]
# # Assignment 2 : U. Rusitha (412519205113)

# %% [markdown]
# ### Importing

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Loading the dataset provided in the assignment folder

# %%
df=pd.read_csv("./data/Churn_Modelling.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# min         0.000000       1.000000      0.00000        0.000000
# 25%         0.000000       1.000000      0.00000        0.000000
# 50%     97198.540000       1.000000      1.00000        1.000000
# 75%    127644.240000       2.000000      1.00000        1.000000
# max    250898.090000       4.000000      1.00000        1.000000
#
#        EstimatedSalary        Exited
# count     10000.000000  10000.000000
# mean     100090.239881      0.203700
# std       57510.492818      0.402769
# min          11.580000      0.000000
# 25%       51002.110000      0.000000
# 50%      100193.915000      0.000000
# 75%      149388.247500      0.000000
# max      199992.480000      1.000000

# %% [markdown]
# ## 1. UNIVARIATE ANALYSIS

# %% [markdown]
# ### Histogram

# %%
sns.displot(df["Age"], color='blue')

# %% [markdown]
# ### In Histogram, we can do it vertically too, by just changing the axis

# %%
sns.histplot(y="Age",data=df,color='yellow')
# Out:
# <AxesSubplot: xlabel='Count', ylabel='Age'>

# %% [markdown]
# ### Now, we can also use Histogram for categorical variables

# %%
sns.histplot(x='Age',data=df,hue=df['Tenure'])
# Out:
# <AxesSubplot: xlabel='Age', ylabel='Count'>

# %% [markdown]
# ### Distplot

# %%
sns.distplot(df["Age"],color='green')
# Out:
# <AxesSubplot: xlabel='Age', ylabel='Density'>

# %% [markdown]
# ### This is visualising displot alone

# %%
sns.distplot(df["Age"],hist=False,color='red')
# Out:
# <AxesSubplot: xlabel='Age', ylabel='Density'>

# %% [markdown]
# ### Boxplot

# %%
sns.boxplot(df["Age"],color='orange')
# Out:
# <AxesSubplot: >

# %% [markdown]
# ### Countplot

# %%
sns.countplot(df['Age'])
# Out:
# <AxesSubplot: ylabel='count'>

# %% [markdown]
# ## 2. BIVARIATE ANALYSIS

# %% [markdown]
# ### Barplot

# %%
sns.barplot(x=df["NumOfProducts"],y=df["Age"])
# Out:
# <AxesSubplot: xlabel='NumOfProducts', ylabel='Age'>

# %% [markdown]
# ### Linearplot

# %%
sns.lineplot(x=df["Age"],y=df["NumOfProducts"], color='green')
# Out:
# <AxesSubplot: xlabel='Age', ylabel='NumOfProducts'>

# %% [markdown]
# ### Scatterplot

# %%
sns.scatterplot(x=df.Age,y=df.RowNumber,color='blue')
# Out:
# <AxesSubplot: xlabel='Age', ylabel='RowNumber'>

# %% [markdown]
# ### Pointplot

# %%
sns.pointplot(x='Age',y='Tenure',data=df,color='red')
# Out:
# <AxesSubplot: xlabel='Age', ylabel='Tenure'>

# %% [markdown]
# ### Regplot

# %%
sns.regplot(x=df['Age'],y=df['Tenure'],color='yellow')
# Out:
# <AxesSubplot: xlabel='Age', ylabel='Tenure'>

# %% [markdown]
# ## 3. MULTI - VARIATE ANALYSIS

# %% [markdown]
# ### Pairplot

# %%
sns.pairplot(data=df[["RowNumber","Age","Tenure","Balance","NumOfProducts"]],kind="kde")

# %%
sns.pairplot(data=df[["RowNumber","Age","Tenure","Balance","NumOfProducts"]], hue="Age", diag_kind="hist")

# %%
sns.pairplot(data=df[["RowNumber","Age","Tenure","Balance","NumOfProducts"]], hue="Age")

# %% [markdown]
# ## 4. Perform descriptive statistics on the dataset

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# min         0.000000       1.000000      0.00000        0.000000
# 25%         0.000000       1.000000      0.00000        0.000000
# 50%     97198.540000       1.000000      1.00000        1.000000
# 75%    127644.240000       2.000000      1.00000        1.000000
# max    250898.090000       4.000000      1.00000        1.000000
#
#        EstimatedSalary        Exited
# count     10000.000000  10000.000000
# mean     100090.239881      0.203700
# std       57510.492818      0.402769
# min          11.580000      0.000000
# 25%       51002.110000      0.000000
# 50%      100193.915000      0.000000
# 75%      149388.247500      0.000000
# max      199992.480000      1.000000

# %% [markdown]
# ## 5. Handle the Missing values.

# %%
df.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %% [markdown]
# ## 6. Find the outliers and replace the outliers

# %%
outlierss=df.quantile(q=(0.25,0.75))

# %%
outlierss
# Out:
#       RowNumber   CustomerId  CreditScore   Age  Tenure    Balance  \
# 0.25    2500.75  15628528.25        584.0  32.0     3.0       0.00
# 0.75    7500.25  15753233.75        718.0  44.0     7.0  127644.24
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0.25            1.0        0.0             0.0       51002.1100     0.0
# 0.75            2.0        1.0             1.0      149388.2475     0.0

# %%
sns.boxplot(df["Age"],color='red')
# Out:
# <AxesSubplot: >

# %%
df["Age"]=np.where(df["Age"]<25,50,df["Age"])

# %%
sns.boxplot(df["Age"],color='maroon')
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## 7. Check for Categorical columns and perform encoding.

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df["Gender"] = le.fit_transform(df["Gender"])
df["Geography"] = le.fit_transform(df["Geography"])

df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore  Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619          0       0   42
# 1          2    15647311      Hill          608          2       0   41
# 2          3    15619304      Onio          502          0       0   42
# 3          4    15701354      Boni          699          0       0   39
# 4          5    15737888  Mitchell          850          2       0   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %% [markdown]
# ## 8. Split the data into dependent and independent variables.

# %%
y = df["Surname"]

# %%
x=df.drop(columns=["Surname"],axis=1)

# %%
x.head()
# Out:
#    RowNumber  CustomerId  CreditScore  Geography  Gender  Age  Tenure  \
# 0          1    15634602          619          0       0   42       2
# 1          2    15647311          608          2       0   41       1
# 2          3    15619304          502          0       0   42       8
# 3          4    15701354          699          0       0   39       1
# 4          5    15737888          850          2       0   43       2
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              1          1               1        101348.88
# 1   83807.86              1          0               1        112542.58
# 2  159660.80              3          1               0        113931.57
# 3       0.00              2          0               0         93826.63
# 4  125510.82              1          1               1         79084.10
#
#    Exited
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0

# %% [markdown]
# ## 9. Scale the independent variables

# %%
names=x.columns
names
# Out:
# Index(['RowNumber', 'CustomerId', 'CreditScore', 'Geography', 'Gender', 'Age',
#        'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember',
#        'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
from sklearn.preprocessing import scale

# %%
X=scale(x)

# %%
X
# Out:
# array([[-1.73187761, -0.78321342, -0.32622142, ...,  0.97024255,
#          0.02188649,  1.97716468],
#        [-1.7315312 , -0.60653412, -0.44003595, ...,  0.97024255,
#          0.21653375, -0.50577476],
#        [-1.73118479, -0.99588476, -1.53679418, ..., -1.03067011,
#          0.2406869 ,  1.97716468],
#        ...,
#        [ 1.73118479, -1.47928179,  0.60498839, ...,  0.97024255,
#         -1.00864308,  1.97716468],
#        [ 1.7315312 , -0.11935577,  1.25683526, ..., -1.03067011,
#         -0.12523071,  1.97716468],
#        [ 1.73187761, -0.87055909,  1.46377078, ..., -1.03067011,
#         -1.07636976, -0.50577476]])

# %%
x = pd.DataFrame(X,columns = names )
x
# Out:
#       RowNumber  CustomerId  CreditScore  Geography    Gender       Age  \
# 0     -1.731878   -0.783213    -0.326221  -0.901886 -1.095988  0.179622
# 1     -1.731531   -0.606534    -0.440036   1.515067 -1.095988  0.080092
# 2     -1.731185   -0.995885    -1.536794  -0.901886 -1.095988  0.179622
# 3     -1.730838    0.144767     0.501521  -0.901886 -1.095988 -0.118968
# 4     -1.730492    0.652659     2.063884   1.515067 -1.095988  0.279152
# ...         ...         ...          ...        ...       ...       ...
# 9995   1.730492   -1.177652     1.246488  -0.901886  0.912419 -0.118968
# 9996   1.730838   -1.682806    -1.391939  -0.901886  0.912419 -0.517088
# 9997   1.731185   -1.479282     0.604988  -0.901886 -1.095988 -0.417558
# 9998   1.731531   -0.119356     1.256835   0.306591  0.912419  0.179622
# 9999   1.731878   -0.870559     1.463771  -0.901886 -1.095988 -1.213798
#
#         Tenure   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0    -1.041760 -1.225848      -0.911583   0.646092        0.970243
# 1    -1.387538  0.117350      -0.911583  -1.547768        0.970243
# 2     1.032908  1.333053       2.527057   0.646092       -1.030670
# 3    -1.387538 -1.225848       0.807737  -1.547768       -1.030670
# 4    -1.041760  0.785728      -0.911583   0.646092        0.970243
# ...        ...       ...            ...        ...             ...
# 9995 -0.004426 -1.225848       0.807737   0.646092       -1.030670
# 9996  1.724464 -0.306379      -0.911583   0.646092        0.970243
# 9997  0.687130 -1.225848      -0.911583  -1.547768        0.970243
# 9998 -0.695982 -0.022608       0.807737   0.646092       -1.030670
# 9999 -0.350204  0.859965      -0.911583   0.646092       -1.030670
#
#       EstimatedSalary    Exited
# 0            0.021886  1.977165
# 1            0.216534 -0.505775
# 2            0.240687  1.977165
# 3           -0.108918 -0.505775
# 4           -0.365276 -0.505775
# ...               ...       ...
# 9995        -0.066419 -0.505775
# 9996         0.027988 -0.505775
# 9997        -1.008643  1.977165
# 9998        -0.125231  1.977165
# 9999        -1.076370 -0.505775
#
# [10000 rows x 13 columns]

# %% [markdown]
# ## 10. Split the data into training and testing

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)
print(x_train.head(5))
print(x_test.head(5))
print(y_train.head(5))
print(y_test.head(5))
# Out:
#       RowNumber  CustomerId  CreditScore  Geography    Gender       Age  \
# 7389   0.827747   -0.195066     0.170424   1.515067 -1.095988 -0.616618
# 9275   1.481077    0.810821    -2.312802   0.306591  0.912419  0.179622
# 2995  -0.694379   -1.507642    -1.195351  -0.901886 -1.095988 -1.114268
# 5316   0.109639    1.243462     0.035916   1.515067  0.912419 -0.019438
# 356   -1.608556   -1.100775     2.063884   1.515067 -1.095988  1.672571
#
#         Tenure   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 7389 -0.004426 -1.225848       0.807737   0.646092       -1.030670
# 9275 -1.387538 -0.012892      -0.911583   0.646092        0.970243
# 2995 -1.041760  0.575076      -0.911583   0.646092       -1.030670
# 5316 -0.004426  0.467955      -0.911583   0.646092       -1.030670
# 356   1.032908  0.806010       0.807737   0.646092        0.970243
#
#       EstimatedSalary    Exited
# 7389         1.108382 -0.505775
# 9275        -0.747592 -0.505775
# 2995         1.487464 -0.505775
# 5316         1.278558 -0.505775
# 356          0.560069 -0.505775
#       RowNumber  CustomerId  CreditScore  Geography    Gender       Age  \
# 9394   1.522299   -1.045250    -0.553850   0.306591 -1.095988 -0.517088
# 898   -1.420801   -0.503813    -1.319512  -0.901886 -1.095988 -0.019438
# 2398  -0.901186   -0.793292     0.573948   1.515067 -1.095988  0.179622
# 5906   0.314021    0.760190     1.422384  -0.901886  0.912419 -0.815678
# 2343  -0.920239    1.042107     0.573948   0.306591  0.912419 -0.218498
#
#         Tenure   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9394  1.032908  0.875323      -0.911583   0.646092        0.970243
# 898  -1.041760  0.424422      -0.911583   0.646092       -1.030670
# 2398  1.032908  0.302927      -0.911583   0.646092        0.970243
# 5906 -0.350204  0.570464      -0.911583  -1.547768       -1.030670
# 2343 -0.004426  1.387129       0.807737   0.646092        0.970243
#
#       EstimatedSalary    Exited
# 9394         1.613046 -0.505775
# 898          0.497532  1.977165
# 2398        -0.423561 -0.505775
# 5906        -0.186439 -0.505775
# 2343         0.618560 -0.505775
# 7389     Mishin
# 9275    Carslaw
# 2995      Moore
# 5316      Ferri
# 356     Simmons
# Name: Surname, dtype: object
# 9394    Upchurch
# 898      Fallaci
# 2398    Morrison
# 5906     Worsnop
# 2343      Gibson
# Name: Surname, dtype: object
